# %%
import nltk
from nltk import tokenize
from nltk.tokenize import TweetTokenizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
tknzr = TweetTokenizer()
from stop_words import get_stop_words
from nltk.stem.porter import PorterStemmer

import seaborn as sns
# %matplotlib inline
sns.set_style("whitegrid")

import pandas as pd
import numbers
# Out:
# /Users/elenajia/anaconda/lib/python3.6/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
import spacy
nlp = spacy.load('en')
from spacy.en import English
parser = English()

# %%
from spacy.symbols import nsubj, dobj, pobj, VERB
from spacy.symbols import *
import numpy as np

# %% [markdown]
# ### test spacy on s_med_5000

# %%
df_s = pd.read_csv('s_thrpy_with_score_first5000.csv')

# %%
def labelMed(sent):
    doc = parser(sent)
    dictionary = {}
    
    for word in doc:
        dictionary[word.orth_] = word.dep_

    # print (dictionary)
    
    res = []
    
    for key, value in dictionary.items():
        if "therapy" in key:
            res.append(value)
        if "therapies" in key:
            res.append(value)
        if "therapist" in key:
            res.append(value)
    
    return '_'.join(res)        
#     return res
    
    # print (res)
    # return dictionary
        
    # if wor.dep == nsubj and possible_subject.head.pos == VERB:
    # verbs.add(possible_subject.head)

# %%
test =  "I'm against taking medication after what I had to deal with in the past but I realized this is my only option to get better."
labelMed(test)
# Out:
# ''

# %%
# df_s

# %%
df_s['dict'] = df_s['sentence'].map(lambda x: labelMed(x))

# %%
# df_s

# %%
def select_nubj_or_obj_or_other(label_list):
    if 'nsubj' in label_list:
        return 1
    elif 'pobj' in label_list or 'dobj' in label_list or 'iobj' in label_list:
        return -1
    else:
        return 0

# %%
df_s['identifier'] = df_s['dict'].map(lambda x: select_nubj_or_obj_or_other(x))

# %%
df_s['sentiment'] = df_s[['pos_vader', 'neu_vader', 'neg_vader']].idxmax(axis=1)

# %%
df_s[['sentence','sentiment']].groupby('sentiment').count()
# Out:
#            sentence
# sentiment
# neg_vader        14
# neu_vader      4969
# pos_vader        17

# %%
df_s['only pos or neg'] = df_s[['pos_vader', 'neg_vader']].idxmax(axis=1)
df_s[['sentence','only pos or neg']].groupby('only pos or neg').count()
# Out:
#                  sentence
# only pos or neg
# neg_vader            1838
# pos_vader            3162

# %% [markdown]
# ## Analysis

# %%
df_s.dict.unique()
# Out:
# array(['dobj', 'pobj', 'conj', 'nsubj', 'compound', 'appos', 'pobj_nsubj',
#        'dobj_pobj', 'attr', 'ROOT', 'dep', 'poss', 'dobj_conj', 'npadvmod',
#        'pobj_dobj', 'nsubj_dobj', 'dative', 'dobj_pobj_nsubj', 'ccomp',
#        'oprd', 'pobj_compound', 'dobj_nsubjpass', 'pobj_pobj', 'nmod',
#        'nsubj_pobj', 'xcomp', 'pobj_compound_compound', 'nsubj_conj',
#        'nsubj_compound', 'compound_pobj', 'pobj_pobj_pobj', 'dobj_dobj',
#        'dobj_nsubj', 'pobj_poss', 'nsubjpass', 'amod', 'compound_nsubj',
#        'pobj_attr', 'compound_dobj', 'pobj_advmod', 'dobj_compound',
#        'pobj_conj', 'conj_compound', 'pobj_dobj_conj', 'pobj_conj_nsubj',
#        'nsubj_nsubj', 'nsubjpass_appos', 'pobj_appos', 'parataxis',
#        'pobj_nsubjpass', 'nsubj_attr', 'det', 'acomp', 'attr_poss',
#        'dobj_pobj_pobj', 'quantmod_pobj', 'conj_pobj', 'poss_pobj', 'intj',
#        'pobj_oprd', 'attr_dobj', 'appos_conj', 'advcl', 'oprd_nsubj',
#        'conj_dobj', 'nummod_nmod', 'conj_conj', 'ccomp_nsubj', 'dobj_nmod',
#        'dep_pobj', 'ROOT_dobj', 'amod_pobj'], dtype=object)

# %%
from collections import Counter

Counter(df_s.dict).most_common(10)
# Out:
# [('pobj', 1826),
#  ('dobj', 1564),
#  ('nsubj', 641),
#  ('conj', 297),
#  ('compound', 227),
#  ('attr', 69),
#  ('appos', 40),
#  ('ROOT', 24),
#  ('pobj_pobj', 24),
#  ('npadvmod', 18)]

# %%
df_s_nsubj = df_s[df_s['identifier'] == 1]
df_s_nsubj.to_csv('s_thrpy_5000_nsubj.csv')

# %%
df_s_obj = df_s[df_s['identifier'] == -1]
df_s_obj.to_csv('s_thrpy_5000_obj.csv')

df_s_other = df_s[df_s['identifier'] == 0]
df_s_other.to_csv('s_thrpy_5000_other.csv')

# %%
def print_score_row(df):
    
    for i in df.index:
        ts = df[df.index==i]
        print( ts[['pos_vader', 'neu_vader', 'neg_vader']])
        print( ts['sentence'].values[0])
    
def returnmost(dataframe, pos):
    pospeech_df = dataframe[dataframe['dict'] == pos][['Unnamed: 0','pos_vader', 'neu_vader', 'neg_vader', 'sentence']]
    pospeech_df = pospeech_df.reset_index(drop=True)
#     print(pospeech_df)
#     print(pospeech_df.sort_values('pos_vader', ascending=False)[:5])
    # Most pos
    print('========== MOST POSITIVE ========== ')
    print_score_row(pospeech_df.sort_values('pos_vader', ascending=False)[:5])
    
    # most neu
    print('========== MOST NEUTRAL ========== ')
    print_score_row(pospeech_df.sort_values('neu_vader', ascending=False)[:5])
    
    # most neg
    print('========== MOST negative ========== ')
    print_score_row(pospeech_df.sort_values('neg_vader', ascending=False)[:5])
    
    # random sample
    ind = np.argsort(np.random.rand(pospeech_df.shape[0]))
    print('========== RANDOM SAMPLE ========== ')
    print_score_row(pospeech_df[[x in ind[:10] for x in pospeech_df.index]])

# %%
returnmost(df_s, 'nsubj')
# Out:
# ========== MOST POSITIVE ==========
#      pos_vader  neu_vader  neg_vader
# 639      0.574      0.426        0.0
# Would a therapist help?
#     pos_vader  neu_vader  neg_vader
# 31      0.509      0.491        0.0
# I need help, therapy doesn't help me, but what does help.
#     pos_vader  neu_vader  neg_vader
# 59      0.455      0.545        0.0
# What is therapy like?
#      pos_vader  neu_vader  neg_vader
# 568      0.432      0.568        0.0
# Basically therapy was amazing for me.
#      pos_vader  neu_vader  neg_vader
# 268      0.421      0.579        0.0
# it's going great, my therapist is awesome but every.
# ========== MOST NEUTRAL ==========
#    pos_vader  neu_vader  neg_vader
# 0        0.0        1.0        0.0
# I've talked to my mom about it and she says that I probably don't need it and if I do, the therapist will prescribe some to me.
#      pos_vader  neu_vader  neg_vader
# 106        0.0        1.0        0.0
# Also, has therapy helped you?
#      pos_vader  neu_vader  neg_vader
# 594        0.0        1.0        0.0
# My therapist told me many of her patients need to switch their medicine 3-4 times before they find the right one for them.
#      pos_vader  neu_vader  neg_vader
# 221        0.0        1.0        0.0
# Is my therapist a nut job?
#      pos_vader  neu_vader  neg_vader
# 590        0.0        1.0        0.0
# Or at least I think  that's where my CB therapist would catch me- which is part of the reason I'm looking for advice from you guys.
# ========== MOST negative ==========
#      pos_vader  neu_vader  neg_vader
# 138        0.0       0.39       0.61
# My therapist just re-diagnosed me with General Anxiety Disorder, Panic Disorder, Agoraphobia and Depression.
#      pos_vader  neu_vader  neg_vader
# 606        0.0      0.481      0.519
# This is a doozy, so...
# &gt;TL;DR: Suffer anxiety and depression, therapy is bad or keeps getting cancelled for weird, understandable reasons, and now I feel really helpless.
#     pos_vader  neu_vader  neg_vader
# 83        0.0      0.487      0.513
# My therapist says I'm not psychotic just super super anxious but I still worry.
#      pos_vader  neu_vader  neg_vader
# 472        0.0      0.554      0.446
# I have severe panic disorder, with depression and OCD with health phobias (not hypochondria, which helped me so much when my old therapist explained it).
#      pos_vader  neu_vader  neg_vader
# 155        0.0      0.571      0.429
# The therapy didn't help, the drugs didn't help.
# ========== RANDOM SAMPLE ==========
#     pos_vader  neu_vader  neg_vader
# 54      0.172      0.828        0.0
# TL;DR: But a question I can't quite ask my therapist, and felt like asking you, was what helped you/allowed you/made you know that your therapist is going to be beneficial?
#      pos_vader  neu_vader  neg_vader
# 117      0.242      0.758        0.0
# My therapist says to at least friend request him on facebook.
#      pos_vader  neu_vader  neg_vader
# 171      0.221      0.659       0.12
# The one therapist who I do trust, but unfortunately he has gotten too old to properly help patients, is Nathaniel Branden.
#      pos_vader  neu_vader  neg_vader
# 196        0.0        1.0        0.0
# (pardon my French)
#
# Ah, &amp; my therapist is on vacation, can't get in for another month.
#      pos_vader  neu_vader  neg_vader
# 280        0.0        1.0        0.0
# What if my therapist is mean?
#      pos_vader  neu_vader  neg_vader
# 432      0.075      0.775       0.15
# Recently my therapist suggested seeing a psychiatrist to evaluate possible medication and he urged me to try as he thought my problems had lasted for too long while only getting worse instead of better.
#      pos_vader  neu_vader  neg_vader
# 463      0.181      0.704      0.116
# well, my therapist suggested when i start feeling that loss of control to have a visual connected to it.
#      pos_vader  neu_vader  neg_vader
# 582        0.0      0.701      0.299
# My therapist says you can go to sleep with tense muscles or become tense at night and that it can cause pain.
#      pos_vader  neu_vader  neg_vader
# 589        0.0      0.902      0.098
# I have a doctors appointment (GP) tomorrow but I don't know exactly what to tell him, my therapist and I have tried a range of things but she basically said to me that if it gets worse or keeps up at the range it is that the only other options are medication or to leave my job.
#      pos_vader  neu_vader  neg_vader
# 622      0.392      0.608        0.0
# I am pretty sure he would be unwilling to agree to some medication for me (not even sure psychotherapists can prescribe?).

# %%
df_s
# Out:
#       Unnamed: 0  neg_prob  pos_prob  neg_vader  neu_vader  pos_vader  \
# 0              0  0.999987  0.000013      0.000      1.000      0.000
# 1              1  0.999968  0.000032      0.000      1.000      0.000
# 2              2  0.999820  0.000180      0.154      0.714      0.132
# 4995        4995  0.999822  0.000178      0.180      0.667      0.154
# 4996        4996  0.999959  0.000041      0.000      1.000      0.000
# 4997        4997  0.999941  0.000059      0.150      0.752      0.098
# 4998        4998  0.999365  0.000635      0.152      0.848      0.000
# 4999        4999  0.999944  0.000056      0.412      0.588      0.000
#
#                                                sentence        dict  \
# 0     I have been recently diagnosed and have just s...        dobj
# 1         I am having an issue concerning my therapist.        dobj
# 2     On one hand I feel I should share this informa...        pobj
# 3     I've tried medications but they only made me f...        pobj
# 4     I think I might have social anxiety (but since...        pobj
# 5     I've been through my share of doctors, therapy...        conj
# 6     I didn't really like going to therapy, I felt ...        pobj
# 7     I've been going to another therapist I kind of...        pobj
# 8     I've talked to my mom about it and she says th...       nsubj
# 9     I scheduled a GP appointment last week and he ...        conj
# 10    My first therapist appt will be next week and ...       nsubj
# 11     I've been to therapy, but it didn't help at all.        pobj
# 12    I'm also trying to find work, or at least some...        dobj
# 13    After about the fifth med he said lets just th...        pobj
# 14    Problem being, the area I'm in is extremely un...        conj
# 15    My doctor refuses to prescribe TCAs or benzos,...        dobj
# 16    This morning I had an intense therapy session,...    compound
# 17     I'm a high school senior and I'd like to get ...       appos
# 18    Another option I could take is using a therapi...        dobj
# 19    He told me to get a doctors note but as I have...        dobj
# 20    I don't see how therapy can really help right ...       nsubj
# 21    I go to the gym several days a week, see a the...        dobj
# 22    I'll try not to make this a wall of text so le...  pobj_nsubj
# 23    I will also look into meditation and possibly ...        conj
# 24    I have to figure out what I want in life and I...        pobj
# 25    So recently I've been thinking about seeing a ...       nsubj
# 26    For those that see/have seen a therapist:  \nW...   dobj_pobj
# 27    Is it normal to start therapy without having a...        dobj
# 28    I am taking the 5-HTP and meeting with a thera...        pobj
# 29    The body needs darkness at night just as much ...        pobj
# ...                                                 ...         ...
# 4970  So I made an elaborate excuse and made my mom ...       nsubj
# 4971  I was very distressed since I felt my last lin...       appos
# 4972                  And so I met my second therapist.        dobj
# 4973   Which is why my previous therapists didn't know.       nsubj
# 4974                       Third and current therapist.        ROOT
# 4975  But my anxiety won't let me mention it to my t...        pobj
# 4976  Do you think I should see a therapist about this?        dobj
# 4977                            Would a therapist help?       nsubj
# 4978  I've been to therapy off and on for years rega...       xcomp
# 4979  While there is heaps of information out there,...        pobj
# 4980  Check Angie’s List for some reviews on therapi...        pobj
# 4981  I often tell my uncle I have social anxiety an...        dobj
# 4982  I don't need months of testing and therapy tha...        conj
# 4983  I've suggested some sliding scale therapists b...   dobj_dobj
# 4984  I am going back to the docs tommorow, I believ...        conj
# 4985  I don't think I can properly illustrate the gr...        dobj
# 4986     Been to a couple therapists, hasn't done much.        pobj
# 4987                              I've seen therapists.        dobj
# 4988  An endless loop of medication, therapy, and an...        conj
# 4989  I regularly meditate but I'd love to hear some...        dobj
# 4990  I will most likely be taking something while I...        pobj
# 4991  This post is not to tell you why, diagnose or ...        pobj
# 4992  As a simple way to summarize the model, ACT vi...       appos
# 4993  [Source](http://www.goodtherapy.org/acceptance...      dative
# 4994  I've tried going to therapists but I never rea...        pobj
# 4995  Can therapy and/or medication really help me o...       nsubj
# 4996   I'm going to my first therapy session on Monday.    compound
# 4997  I want to try just therapy alone and see where...        dobj
# 4998  I'm in therapy and on medication, but when I'm...        pobj
# 4999  I've recently been seeing a therapist for my a...        dobj
#
#       identifier  sentiment only pos or neg
# 0             -1  neu_vader       pos_vader
# 1             -1  neu_vader       pos_vader
# 2             -1  neu_vader       neg_vader
# 3             -1  neu_vader       pos_vader
# 4             -1  neu_vader       neg_vader
# 5              0  neu_vader       neg_vader
# 6             -1  neu_vader       neg_vader
# 7             -1  neu_vader       pos_vader
# 8              1  neu_vader       pos_vader
# 9              0  neu_vader       neg_vader
# 10             1  neu_vader       pos_vader
# 11            -1  neu_vader       neg_vader
# 12            -1  neu_vader       neg_vader
# 13            -1  neu_vader       pos_vader
# 14             0  neu_vader       neg_vader
# 15            -1  neu_vader       neg_vader
# 16             0  neu_vader       pos_vader
# 17             0  neu_vader       pos_vader
# 18            -1  neu_vader       pos_vader
# 19            -1  neu_vader       pos_vader
# 20             1  neu_vader       pos_vader
# 21            -1  neu_vader       pos_vader
# 22             1  neu_vader       pos_vader
# 23             0  neu_vader       pos_vader
# 24            -1  neu_vader       pos_vader
# 25             1  neu_vader       pos_vader
# 26            -1  neu_vader       pos_vader
# 27            -1  neu_vader       pos_vader
# 28            -1  neu_vader       neg_vader
# 29            -1  neu_vader       neg_vader
# ...          ...        ...             ...
# 4970           1  neu_vader       pos_vader
# 4971           0  neu_vader       neg_vader
# 4972          -1  neu_vader       pos_vader
# 4973           1  neu_vader       pos_vader
# 4974           0  neu_vader       pos_vader
# 4975          -1  neu_vader       neg_vader
# 4976          -1  neu_vader       pos_vader
# 4977           1  pos_vader       pos_vader
# 4978           0  neu_vader       neg_vader
# 4979          -1  neu_vader       neg_vader
# 4980          -1  neu_vader       pos_vader
# 4981          -1  neu_vader       neg_vader
# 4982           0  neu_vader       pos_vader
# 4983          -1  neu_vader       pos_vader
# 4984           0  neu_vader       neg_vader
# 4985          -1  neu_vader       pos_vader
# 4986          -1  neu_vader       pos_vader
# 4987          -1  neu_vader       pos_vader
# 4988           0  neu_vader       neg_vader
# 4989          -1  neu_vader       pos_vader
# 4990          -1  neu_vader       pos_vader
# 4991          -1  neu_vader       pos_vader
# 4992           0  neu_vader       pos_vader
# 4993           0  neu_vader       neg_vader
# 4994          -1  neu_vader       pos_vader
# 4995           1  neu_vader       neg_vader
# 4996           0  neu_vader       pos_vader
# 4997          -1  neu_vader       neg_vader
# 4998          -1  neu_vader       neg_vader
# 4999          -1  neu_vader       neg_vader
#
# [5000 rows x 11 columns]

# %%
## maybe look closer at SA

# %%
df_s_nsubj
# Out:
#       Unnamed: 0  neg_prob  pos_prob  neg_vader  neu_vader  pos_vader  \
# 8              8  0.999736  0.000264      0.000      1.000      0.000
# 10            10  0.999781  0.000219      0.042      0.595      0.363
# 20            20  0.999960  0.000040      0.000      0.870      0.130
# 4934  I think getting to see a therapist may be the ...       nsubj
# 4939  My therapist suggested it and I was wondering ...       nsubj
# 4941  They always told me a therapist would brainwas...       nsubj
# 4949  My therapist suggested I would be able to skip...       nsubj
# 4962  I've been in and out of therapy but never real...  pobj_nsubj
# 4964  As for treatments go, I'm currently in ADHD co...       nsubj
# 4970  So I made an elaborate excuse and made my mom ...       nsubj
# 4973   Which is why my previous therapists didn't know.       nsubj
# 4977                            Would a therapist help?       nsubj
# 4995  Can therapy and/or medication really help me o...       nsubj
#
#       identifier  sentiment only pos or neg
# 8              1  neu_vader       pos_vader
# 10             1  neu_vader       pos_vader
# 20             1  neu_vader       pos_vader
# 22             1  neu_vader       pos_vader
# 25             1  neu_vader       pos_vader
# 32             1  neu_vader       pos_vader
# 35             1  neu_vader       pos_vader
# 53             1  neu_vader       neg_vader
# 54             1  neu_vader       neg_vader
# 58             1  neu_vader       pos_vader
# 62             1  neu_vader       pos_vader
# 77             1  neu_vader       neg_vader
# 78             1  neu_vader       pos_vader
# 95             1  neu_vader       pos_vader
# 107            1  neu_vader       neg_vader
# 117            1  neu_vader       pos_vader
# 118            1  neu_vader       neg_vader
# 136            1  neu_vader       neg_vader
# 137            1  neu_vader       pos_vader
# 143            1  neu_vader       neg_vader
# 153            1  neu_vader       pos_vader
# 157            1  neu_vader       neg_vader
# 165            1  neu_vader       neg_vader
# 181            1  neu_vader       pos_vader
# 182            1  neu_vader       pos_vader
# 191            1  neu_vader       pos_vader
# 194            1  neu_vader       neg_vader
# 197            1  neu_vader       neg_vader
# 212            1  neu_vader       pos_vader
# 217            1  neu_vader       pos_vader
# ...          ...        ...             ...
# 4770           1  neu_vader       pos_vader
# 4782           1  neu_vader       neg_vader
# 4788           1  neu_vader       neg_vader
# 4790           1  neu_vader       pos_vader
# 4806           1  neu_vader       neg_vader
# 4809           1  neu_vader       neg_vader
# 4818           1  neu_vader       neg_vader
# 4846           1  neu_vader       pos_vader
# 4848           1  neu_vader       pos_vader
# 4851           1  neu_vader       pos_vader
# 4858           1  neu_vader       neg_vader
# 4859           1  neu_vader       pos_vader
# 4869           1  neu_vader       neg_vader
# 4876           1  neu_vader       neg_vader
# 4892           1  neu_vader       neg_vader
# 4899           1  neu_vader       neg_vader
# 4919           1  neu_vader       pos_vader
# 4921           1  neu_vader       pos_vader
# 4928           1  neu_vader       pos_vader
# 4932           1  neu_vader       pos_vader
# 4934           1  neu_vader       pos_vader
# 4939           1  neu_vader       pos_vader
# 4941           1  neu_vader       neg_vader
# 4949           1  neu_vader       pos_vader
# 4962           1  neu_vader       neg_vader
# 4964           1  neu_vader       pos_vader
# 4970           1  neu_vader       pos_vader
# 4973           1  neu_vader       pos_vader
# 4977           1  pos_vader       pos_vader
# 4995           1  neu_vader       neg_vader
#
# [724 rows x 11 columns]

# %%
ax2 = sns.boxplot(data = df_s_nsubj.loc[:,['neg_prob','pos_prob','neg_vader','neu_vader','pos_vader']], palette = "PRGn")

# %%
df_s_obj
# Out:
# 4981  I often tell my uncle I have social anxiety an...       dobj
# 4983  I've suggested some sliding scale therapists b...  dobj_dobj
# 4985  I don't think I can properly illustrate the gr...       dobj
# 4986     Been to a couple therapists, hasn't done much.       pobj
# 4987                              I've seen therapists.       dobj
# 4989  I regularly meditate but I'd love to hear some...       dobj
# 4990  I will most likely be taking something while I...       pobj
# 4991  This post is not to tell you why, diagnose or ...       pobj
# 4994  I've tried going to therapists but I never rea...       pobj
# 4997  I want to try just therapy alone and see where...       dobj
# 4998  I'm in therapy and on medication, but when I'm...       pobj
# 4999  I've recently been seeing a therapist for my a...       dobj
#
#       identifier  sentiment only pos or neg
# 0             -1  neu_vader       pos_vader
# 1             -1  neu_vader       pos_vader
# 2             -1  neu_vader       neg_vader
# 3             -1  neu_vader       pos_vader
# 4             -1  neu_vader       neg_vader
# 6             -1  neu_vader       neg_vader
# 7             -1  neu_vader       pos_vader
# 11            -1  neu_vader       neg_vader
# 12            -1  neu_vader       neg_vader
# 13            -1  neu_vader       pos_vader
# 15            -1  neu_vader       neg_vader
# 18            -1  neu_vader       pos_vader
# 19            -1  neu_vader       pos_vader
# 21            -1  neu_vader       pos_vader
# 24            -1  neu_vader       pos_vader
# 26            -1  neu_vader       pos_vader
# 27            -1  neu_vader       pos_vader
# 28            -1  neu_vader       neg_vader
# 29            -1  neu_vader       neg_vader
# 30            -1  neu_vader       neg_vader
# 31            -1  neu_vader       pos_vader
# 34            -1  neu_vader       neg_vader
# 36            -1  neu_vader       pos_vader
# 37            -1  neu_vader       neg_vader
# 38            -1  neu_vader       pos_vader
# 39            -1  neu_vader       pos_vader
# 40            -1  neu_vader       pos_vader
# 41            -1  neu_vader       pos_vader
# 42            -1  neu_vader       pos_vader
# 43            -1  neu_vader       pos_vader
# ...          ...        ...             ...
# 4954          -1  neu_vader       pos_vader
# 4955          -1  neu_vader       pos_vader
# 4956          -1  neu_vader       neg_vader
# 4957          -1  neu_vader       neg_vader
# 4958          -1  neu_vader       neg_vader
# 4959          -1  neu_vader       pos_vader
# 4960          -1  neu_vader       pos_vader
# 4961          -1  neu_vader       pos_vader
# 4963          -1  neu_vader       neg_vader
# 4965          -1  neu_vader       pos_vader
# 4966          -1  neu_vader       pos_vader
# 4968          -1  neu_vader       neg_vader
# 4969          -1  neu_vader       pos_vader
# 4972          -1  neu_vader       pos_vader
# 4975          -1  neu_vader       neg_vader
# 4976          -1  neu_vader       pos_vader
# 4979          -1  neu_vader       neg_vader
# 4980          -1  neu_vader       pos_vader
# 4981          -1  neu_vader       neg_vader
# 4983          -1  neu_vader       pos_vader
# 4985          -1  neu_vader       pos_vader
# 4986          -1  neu_vader       pos_vader
# 4987          -1  neu_vader       pos_vader
# 4989          -1  neu_vader       pos_vader
# 4990          -1  neu_vader       pos_vader
# 4991          -1  neu_vader       pos_vader
# 4994          -1  neu_vader       pos_vader
# 4997          -1  neu_vader       neg_vader
# 4998          -1  neu_vader       neg_vader
# 4999          -1  neu_vader       neg_vader
#
# 4903  I'd like a low dose of some sort of benzo and ...      conj           0
# 4908  Been diagnosed since 2012, been on Lexapro sin...  compound           0
# 4911        I started medication and therapy at age 19.      conj           0
# 4913  Years and years and years of hard work, medica...      conj           0
# 4920  However, I have yet to find a new shrink or th...      conj           0
# 4927  She has been talking me through CBT, but its t...      conj           0
# 4943                tldr: Need a group therapy session.  compound           0
# 4944                                       A therapist?      ROOT           0
# 4948  Tomorrow, I have my first therapy session ever...  compound           0
# 4967  I had a total of three; the third one is my cu...      attr           0
# 4971  I was very distressed since I felt my last lin...     appos           0
# 4974                       Third and current therapist.      ROOT           0
# 4978  I've been to therapy off and on for years rega...     xcomp           0
# 4982  I don't need months of testing and therapy tha...      conj           0
# 4984  I am going back to the docs tommorow, I believ...      conj           0
# 4988  An endless loop of medication, therapy, and an...      conj           0
# 4992  As a simple way to summarize the model, ACT vi...     appos           0
# 4993  [Source](http://www.goodtherapy.org/acceptance...    dative           0
# 4996   I'm going to my first therapy session on Monday.  compound           0
#
#       sentiment only pos or neg
# 5     neu_vader       neg_vader
# 9     neu_vader       neg_vader
# 14    neu_vader       neg_vader
# 16    neu_vader       pos_vader
# 17    neu_vader       pos_vader
# 23    neu_vader       pos_vader
# 33    neu_vader       pos_vader
# 82    neu_vader       pos_vader
# 87    neu_vader       pos_vader
# 90    neu_vader       pos_vader
# 103   neu_vader       pos_vader
# 116   neu_vader       pos_vader
# 120   neu_vader       neg_vader
# 122   neu_vader       neg_vader
# 124   neu_vader       pos_vader
# 132   neu_vader       neg_vader
# 133   neu_vader       pos_vader
# 134   neu_vader       neg_vader
# 145   neu_vader       pos_vader
# 151   neu_vader       pos_vader
# 155   neu_vader       neg_vader
# 161   neu_vader       pos_vader
# 170   neu_vader       pos_vader
# 176   neu_vader       pos_vader
# 178   neu_vader       neg_vader
# 180   neu_vader       pos_vader
# 184   neu_vader       pos_vader
# 185   neu_vader       pos_vader
# 186   neu_vader       neg_vader
# 188   neu_vader       pos_vader
# ...         ...             ...
# 4833  neu_vader       pos_vader
# 4834  neu_vader       pos_vader
# 4835  neu_vader       pos_vader
# 4841  neu_vader       pos_vader
# 4842  neu_vader       neg_vader
# 4843  neu_vader       pos_vader
# 4857  neu_vader       pos_vader
# 4863  neu_vader       pos_vader
# 4880  neu_vader       neg_vader
# 4889  neu_vader       neg_vader
# 4893  neu_vader       pos_vader
# 4903  neu_vader       pos_vader
# 4908  neu_vader       neg_vader
# 4911  neu_vader       pos_vader
# 4913  neu_vader       pos_vader
# 4920  neu_vader       pos_vader
# 4927  neu_vader       neg_vader
# 4943  neu_vader       pos_vader
# 4944  neu_vader       pos_vader
# 4948  neu_vader       neg_vader
# 4967  neu_vader       pos_vader
# 4971  neu_vader       neg_vader
# 4974  neu_vader       pos_vader
# 4978  neu_vader       neg_vader
# 4982  neu_vader       pos_vader
# 4984  neu_vader       neg_vader
# 4988  neu_vader       neg_vader
# 4992  neu_vader       pos_vader
# 4993  neu_vader       neg_vader
# 4996  neu_vader       pos_vader
#
# [771 rows x 11 columns]

# %%
ax2 = sns.boxplot(data = df_s_other.loc[:,['neg_prob','pos_prob','neg_vader','neu_vader','pos_vader']], palette = "PRGn")

# %% [markdown]
# ### spacy: posts_5000 identify

# %%
df_p = pd.read_csv('p_thrpy_with_score_first5000.csv')

# %%
def labelMed2(post):
    post = str(post)
    
    doc = parser(post)
    dictionary = {}
    
    for word in doc:
        dictionary[word.orth_] = word.dep_

    # print (dictionary)
    
    res = []
    
    for key, value in dictionary.items():
        if "therapy" in key:
            res.append(value)
        if "therapies" in key:
            res.append(value)
        if "therapist" in key:
            res.append(value)
            
    return res

# %%
df_p['dict'] = df_p['post'].map(lambda x: labelMed2(x))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-4c136b5e5960> in <module>()
# ----> 1 df_p['dict'] = df_p['post'].map(lambda x: labelMed2(x))
#
# /Users/elenajia/anaconda/lib/python3.6/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    2175             new_values = algos.take_1d(arg._values, indexer)
#    2176         else:
# -> 2177             new_values = map_f(values, arg)
#    2178
#    2179         return self._constructor(new_values,
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:66124)()
#
# <ipython-input-31-4c136b5e5960> in <lambda>(x)
# ----> 1 df_p['dict'] = df_p['post'].map(lambda x: labelMed2(x))
#
# <ipython-input-30-87f90b4885a8> in labelMed2(post)
#       2     post = str(post)
#       3
# ----> 4     doc = parser(post)
#       5     dictionary = {}
#       6
#
# /Users/elenajia/anaconda/lib/python3.6/site-packages/spacy/language.py in __call__(self, text, tag, parse, entity)
#     229             self.matcher(tokens)
#     230         if self.parser and parse:
# --> 231             self.parser(tokens)
#     232         if self.entity and entity:
#     233             # Add any of the entity labels already set, in case we don't have them.
#
# /Users/elenajia/anaconda/lib/python3.6/site-packages/spacy/syntax/parser.pyx in spacy.syntax.parser.Parser.__call__ (spacy/syntax/parser.cpp:6192)()
#
# KeyboardInterrupt:

# %%
df_p['identifier'] = df_p['dict'].map(lambda x: select_nubj_or_obj_or_other(x))

# %%
df_p['sentiment'] = df_p[['pos_vader', 'neu_vader', 'neg_vader']].idxmax(axis=1)

# %%
df_p

# %%
df_p_nsubj = df_p[df_p['identifier'] == 1]
df_p_nsubj.to_csv('p_thrpy_5000_nsubj.csv')

df_p_obj = df_p[df_p['identifier'] == -1]
df_p_obj.to_csv('p_thrpy_5000_obj.csv')

df_p_other = df_p[df_p['identifier'] == 0]
df_p_other.to_csv('p_thrpy_5000_other.csv')

# %%
df_p_nsubj

# %%
ax1 = sns.boxplot(data = df_p_nsubj.loc[:,['neg_prob','pos_prob','neg_vader','neu_vader','pos_vader']], palette = "PRGn")

# %%
ax2 = sns.boxplot(data = df_p_obj.loc[:,['neg_prob','pos_prob','neg_vader','neu_vader','pos_vader']], palette = "PRGn")

# %%
df_p_obj

# %%
ax2 = sns.boxplot(data = df_p_obj.loc[:,['neg_prob','pos_prob','neg_vader','neu_vader','pos_vader']], palette = "PRGn")

# %%
df_p_other

# %%
ax = sns.boxplot(data = df_p_other.loc[:,['neg_prob','pos_prob','neg_vader','neu_vader','pos_vader']], palette = "PRGn")
